# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # DATAFRAME da Premier League 12/13

# %%
df_12_13 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=2137")

# %%
df_PL1213 = df_12_13[0]

# %%
df_PL1213
# Out:
#      #                 Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0    1       Manchester Utd   89         NaN  38  28   5   5  86  43   43
# 1    2      Manchester City   78         NaN  38  23   9   6  66  34   32
# 2    3              Chelsea   75         NaN  38  22   9   7  75  39   36
# 3    4              Arsenal   73         NaN  38  21  10   7  72  37   35
# 4    5            Tottenham   72         NaN  38  21   9   8  66  46   20
# 5    6              Everton   63         NaN  38  16  15   7  55  40   15
# 6    7            Liverpool   61         NaN  38  16  13   9  71  43   28
# 7    8        West Bromwich   49         NaN  38  14   7  17  53  57   -4
# 8    9              Swansea   46         NaN  38  11  13  14  47  51   -4
# 9   10             West Ham   46         NaN  38  12  10  16  45  53   -8
# 10  11              Norwich   44         NaN  38  10  14  14  41  58  -17
# 11  12               Fulham   43         NaN  38  11  10  17  50  60  -10
# ...

# %%
classificados1213 = df_PL1213["#"] < 5

# %%
df_classPL1213 = df_PL1213[classificados1213]

# %%
df_classPL1213
# Out:
#    #             Time  pts  Unnamed: 3   j   v   e  d   +   -  +/-
# 0  1   Manchester Utd   89         NaN  38  28   5  5  86  43   43
# 1  2  Manchester City   78         NaN  38  23   9  6  66  34   32
# 2  3          Chelsea   75         NaN  38  22   9  7  75  39   36
# 3  4          Arsenal   73         NaN  38  21  10  7  72  37   35

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame da Premier League 13/14

# %%
df_13_14 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=4301")

# %%
df_PL1314 = df_13_14[0]

# %%
df_PL1314
# Out:
#      #             Time  pts  Unnamed: 3   j   v   e   d    +   -  +/-
# 0    1  Manchester City   86         NaN  38  27   5   6  102  37   65
# 1    2        Liverpool   84         NaN  38  26   6   6  101  50   51
# 2    3          Chelsea   82         NaN  38  25   7   6   71  27   44
# 3    4          Arsenal   79         NaN  38  24   7   7   68  41   27
# 4    5          Everton   72         NaN  38  21   9   8   61  39   22
# 5    6        Tottenham   69         NaN  38  21   6  11   55  51    4
# 6    7   Manchester Utd   64         NaN  38  19   7  12   64  43   21
# 7    8      Southampton   56         NaN  38  15  11  12   54  46    8
# 8    9            Stoke   50         NaN  38  13  11  14   45  52   -7
# 9   10        Newcastle   49         NaN  38  15   4  19   43  59  -16
# 10  11   Crystal Palace   45         NaN  38  13   6  19   33  48  -15
# 11  12          Swansea   42         NaN  38  11   9  18   54  54    0
# ...

# %%
classificados1314 = df_PL1314["#"] < 5

# %%
df_classPL1314 = df_PL1314[classificados1314]

# %%
df_classPL1314
# Out:
#    #             Time  pts  Unnamed: 3   j   v  e  d    +   -  +/-
# 0  1  Manchester City   86         NaN  38  27  5  6  102  37   65
# 1  2        Liverpool   84         NaN  38  26  6  6  101  50   51
# 2  3          Chelsea   82         NaN  38  25  7  6   71  27   44
# 3  4          Arsenal   79         NaN  38  24  7  7   68  41   27

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame da Premier League 14/15

# %%
df_14_15 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=6195")

# %%
df_PL1415 = df_14_15[0]

# %%
df_PL1415
# Out:
#      #                 Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0    1              Chelsea   87         NaN  38  26   9   3  73  32   41
# 1    2      Manchester City   79         NaN  38  24   7   7  83  38   45
# 2    3              Arsenal   75         NaN  38  22   9   7  71  36   35
# 3    4       Manchester Utd   70         NaN  38  20  10   8  62  37   25
# 4    5            Tottenham   64         NaN  38  19   7  12  58  53    5
# 5    6            Liverpool   62         NaN  38  18   8  12  52  48    4
# 6    7          Southampton   60         NaN  38  18   6  14  54  33   21
# 7    8              Swansea   56         NaN  38  16   8  14  46  49   -3
# 8    9                Stoke   54         NaN  38  15   9  14  48  45    3
# 9   10       Crystal Palace   48         NaN  38  13   9  16  47  51   -4
# 10  11              Everton   47         NaN  38  12  11  15  48  50   -2
# 11  12             West Ham   47         NaN  38  12  11  15  44  47   -3
# ...

# %%
classificados1415 = df_PL1415["#"] < 5

# %%
df_classPL1415 = df_PL1415[classificados1415]

# %%
df_classPL1415
# Out:
#    #             Time  pts  Unnamed: 3   j   v   e  d   +   -  +/-
# 0  1          Chelsea   87         NaN  38  26   9  3  73  32   41
# 1  2  Manchester City   79         NaN  38  24   7  7  83  38   45
# 2  3          Arsenal   75         NaN  38  22   9  7  71  36   35
# 3  4   Manchester Utd   70         NaN  38  20  10  8  62  37   25

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #--------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame Premier League 15/16

# %%
df_15_16 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=6871")

# %%
df_PL1516 = df_15_16[0]

# %%
df_PL1516
# Out:
#      #             Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0    1        Leicester   81         NaN  38  23  12   3  68  36   32
# 1    2          Arsenal   71         NaN  38  20  11   7  65  36   29
# 2    3        Tottenham   70         NaN  38  19  13   6  69  35   34
# 3    4  Manchester City   66         NaN  38  19   9  10  71  41   30
# 4    5   Manchester Utd   66         NaN  38  19   9  10  49  35   14
# 5    6      Southampton   63         NaN  38  18   9  11  59  41   18
# 6    7         West Ham   62         NaN  38  16  14   8  65  51   14
# 7    8        Liverpool   60         NaN  38  16  12  10  63  50   13
# 8    9            Stoke   51         NaN  38  14   9  15  41  55  -14
# 9   10          Chelsea   50         NaN  38  12  14  12  59  53    6
# 10  11          Everton   47         NaN  38  11  14  13  59  55    4
# 11  12          Swansea   47         NaN  38  12  11  15  42  52  -10
# ...

# %%
classificados1516 = df_PL1516["#"] < 5

# %%
df_classPL1516 = df_PL1516[classificados1516]

# %%
df_classPL1516
# Out:
#    #             Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0  1        Leicester   81         NaN  38  23  12   3  68  36   32
# 1  2          Arsenal   71         NaN  38  20  11   7  65  36   29
# 2  3        Tottenham   70         NaN  38  19  13   6  69  35   34
# 3  4  Manchester City   66         NaN  38  19   9  10  71  41   30

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #-----------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame Premier League 16/17

# %%
df_16_17 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=20809")

# %%
df_PL1617 = df_16_17[0]

# %%
df_PL1617
# Out:
#      #             Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0    1          Chelsea   93         NaN  38  30   3   5  85  33   52
# 1    2        Tottenham   86         NaN  38  26   8   4  86  26   60
# 2    3  Manchester City   78         NaN  38  23   9   6  80  39   41
# 3    4        Liverpool   76         NaN  38  22  10   6  78  42   36
# 4    5          Arsenal   75         NaN  38  23   6   9  77  44   33
# 5    6   Manchester Utd   69         NaN  38  18  15   5  54  29   25
# 6    7          Everton   61         NaN  38  17  10  11  62  44   18
# 7    8      Southampton   46         NaN  38  12  10  16  41  48   -7
# 8    9      Bournemouth   46         NaN  38  12  10  16  55  67  -12
# 9   10    West Bromwich   45         NaN  38  12   9  17  43  51   -8
# 10  11         West Ham   45         NaN  38  12   9  17  47  64  -17
# 11  12        Leicester   44         NaN  38  12   8  18  48  63  -15
# ...

# %%
classificados1617 = df_PL1617["#"] < 5

# %%
df_classPL1617 = df_PL1617[classificados1617]

# %%
df_classPL1617
# Out:
#    #             Time  pts  Unnamed: 3   j   v   e  d   +   -  +/-
# 0  1          Chelsea   93         NaN  38  30   3  5  85  33   52
# 1  2        Tottenham   86         NaN  38  26   8  4  86  26   60
# 2  3  Manchester City   78         NaN  38  23   9  6  80  39   41
# 3  4        Liverpool   76         NaN  38  22  10  6  78  42   36

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame Premier League 17/18

# %%
df_17_18 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=26131")

# %%
df_PL1718 = df_17_18[0]

# %%
df_PL1718
# Out:
#      #             Time  pts  Unnamed: 3   j   v   e   d    +   -  +/-
# 0    1  Manchester City  100         NaN  38  32   4   2  106  27   79
# 1    2   Manchester Utd   81         NaN  38  25   6   7   68  28   40
# 2    3        Tottenham   77         NaN  38  23   8   7   74  36   38
# 3    4        Liverpool   75         NaN  38  21  12   5   84  38   46
# 4    5          Chelsea   70         NaN  38  21   7  10   62  38   24
# 5    6          Arsenal   63         NaN  38  19   6  13   74  51   23
# 6    7          Burnley   54         NaN  38  14  12  12   36  39   -3
# 7    8          Everton   49         NaN  38  13  10  15   44  58  -14
# 8    9        Leicester   47         NaN  38  12  11  15   56  60   -4
# 9   10        Newcastle   44         NaN  38  12   8  18   39  47   -8
# 10  11   Crystal Palace   44         NaN  38  11  11  16   45  55  -10
# 11  12      Bournemouth   44         NaN  38  11  11  16   45  61  -16
# ...

# %%
classificados1718 = df_PL1718["#"] < 5

# %%
df_classPL1718 = df_PL1718[classificados1718]

# %%
df_classPL1718
# Out:
#    #             Time  pts  Unnamed: 3   j   v   e  d    +   -  +/-
# 0  1  Manchester City  100         NaN  38  32   4  2  106  27   79
# 1  2   Manchester Utd   81         NaN  38  25   6  7   68  28   40
# 2  3        Tottenham   77         NaN  38  23   8  7   74  36   38
# 3  4        Liverpool   75         NaN  38  21  12  5   84  38   46

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #----------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame Premier League 18/19

# %%
df_18_19 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=28406")

# %%
df_PL1819 = df_18_19[0]

# %%
df_PL1819
# Out:
#      #             Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0    1  Manchester City   98         NaN  38  32   2   4  95  23   72
# 1    2        Liverpool   97         NaN  38  30   7   1  89  22   67
# 2    3          Chelsea   72         NaN  38  21   9   8  63  39   24
# 3    4        Tottenham   71         NaN  38  23   2  13  67  39   28
# 4    5          Arsenal   70         NaN  38  21   7  10  73  51   22
# 5    6   Manchester Utd   66         NaN  38  19   9  10  65  54   11
# 6    7    Wolverhampton   57         NaN  38  16   9  13  47  46    1
# 7    8          Everton   54         NaN  38  15   9  14  54  46    8
# 8    9        Leicester   52         NaN  38  15   7  16  51  48    3
# 9   10         West Ham   52         NaN  38  15   7  16  52  55   -3
# 10  11          Watford   50         NaN  38  14   8  16  52  59   -7
# 11  12   Crystal Palace   49         NaN  38  14   7  17  51  53   -2
# ...

# %%
classificados1819 = df_PL1819["#"] < 5

# %%
df_classPL1819 = df_PL1819[classificados1819]

# %%
df_classPL1819
# Out:
#    #             Time  pts  Unnamed: 3   j   v  e   d   +   -  +/-
# 0  1  Manchester City   98         NaN  38  32  2   4  95  23   72
# 1  2        Liverpool   97         NaN  38  30  7   1  89  22   67
# 2  3          Chelsea   72         NaN  38  21  9   8  63  39   24
# 3  4        Tottenham   71         NaN  38  23  2  13  67  39   28

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #-------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame Premier League 19/20

# %%
df_19_20 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=29475")

# %%
df_PL1920 = df_19_20[0]

# %%
df_PL1920
# Out:
#      #              Time  pts  Unnamed: 3   j   v   e   d    +   -  +/-
# 0    1         Liverpool   99         NaN  38  32   3   3   85  33   52
# 1    2   Manchester City   81         NaN  38  26   3   9  102  35   67
# 2    3    Manchester Utd   66         NaN  38  18  12   8   66  36   30
# 3    4           Chelsea   66         NaN  38  20   6  12   69  54   15
# 4    5         Leicester   62         NaN  38  18   8  12   67  41   26
# 5    6         Tottenham   59         NaN  38  16  11  11   61  47   14
# 6    7     Wolverhampton   59         NaN  38  15  14   9   51  40   11
# 7    8           Arsenal   56         NaN  38  14  14  10   56  48    8
# 8    9  Sheffield United   54         NaN  38  14  12  12   39  39    0
# 9   10           Burnley   54         NaN  38  15   9  14   43  50   -7
# 10  11       Southampton   52         NaN  38  15   7  16   51  60   -9
# 11  12           Everton   49         NaN  38  13  10  15   44  56  -12
# ...

# %%
classificados1920 = df_PL1920["#"] < 5

# %%
df_classPL1920 = df_PL1920[classificados1920]

# %%
df_classPL1920
# Out:
#    #             Time  pts  Unnamed: 3   j   v   e   d    +   -  +/-
# 0  1        Liverpool   99         NaN  38  32   3   3   85  33   52
# 1  2  Manchester City   81         NaN  38  26   3   9  102  35   67
# 2  3   Manchester Utd   66         NaN  38  18  12   8   66  36   30
# 3  4          Chelsea   66         NaN  38  20   6  12   69  54   15

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame Premier League 20/21

# %%
df_20_21 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=30654")

# %%
df_PL2021 = df_20_21[0]

# %%
df_PL2021
# Out:
#      #              Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0    1   Manchester City   86         NaN  38  27   5   6  83  32   51
# 1    2    Manchester Utd   74         NaN  38  21  11   6  73  44   29
# 2    3         Liverpool   69         NaN  38  20   9   9  68  42   26
# 3    4           Chelsea   67         NaN  38  19  10   9  58  36   22
# 4    5         Leicester   66         NaN  38  20   6  12  68  50   18
# 5    6          West Ham   65         NaN  38  19   8  11  62  47   15
# 6    7         Tottenham   62         NaN  38  18   8  12  68  45   23
# 7    8           Arsenal   61         NaN  38  18   7  13  55  39   16
# 8    9             Leeds   59         NaN  38  18   5  15  62  54    8
# 9   10           Everton   59         NaN  38  17   8  13  47  48   -1
# 10  11       Aston Villa   55         NaN  38  16   7  15  55  46    9
# 11  12         Newcastle   45         NaN  38  12   9  17  46  62  -16
# ...

# %%
classificados2021 = df_PL2021["#"] < 5

# %%
df_classPL2021 = df_PL2021[classificados2021]

# %%
df_classPL2021
# Out:
#    #             Time  pts  Unnamed: 3   j   v   e  d   +   -  +/-
# 0  1  Manchester City   86         NaN  38  27   5  6  83  32   51
# 1  2   Manchester Utd   74         NaN  38  21  11  6  73  44   29
# 2  3        Liverpool   69         NaN  38  20   9  9  68  42   26
# 3  4          Chelsea   67         NaN  38  19  10  9  58  36   22

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame Premier League 21/22

# %%
df_21_22 = pd.read_html("https://www.futebol.com/futebol/inglaterra/premier-league/classificacoes.html?competitionSeasonId=31345")

# %%
df_PL2122 = df_21_22[0]

# %%
df_PL2122
# Out:
#      #             Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0    1  Manchester City   93         NaN  38  29   6   3  99  26   73
# 1    2        Liverpool   92         NaN  38  28   8   2  94  26   68
# 2    3          Chelsea   74         NaN  38  21  11   6  76  33   43
# 3    4        Tottenham   71         NaN  38  22   5  11  69  40   29
# 4    5          Arsenal   69         NaN  38  22   3  13  61  48   13
# 5    6   Manchester Utd   58         NaN  38  16  10  12  57  57    0
# 6    7         West Ham   56         NaN  38  16   8  14  60  51    9
# 7    8        Leicester   52         NaN  38  14  10  14  61  59    2
# 8    9         Brighton   51         NaN  38  12  15  11  42  44   -2
# 9   10    Wolverhampton   51         NaN  38  15   6  17  38  43   -5
# 10  11        Newcastle   49         NaN  38  13  10  15  44  62  -18
# 11  12   Crystal Palace   48         NaN  38  11  15  12  50  46    4
# ...

# %%
classificados2122 = df_PL2122["#"] < 5

# %%
df_classPL2122 = df_PL2122[classificados2122]

# %%
df_classPL2122
# Out:
#    #             Time  pts  Unnamed: 3   j   v   e   d   +   -  +/-
# 0  1  Manchester City   93         NaN  38  29   6   3  99  26   73
# 1  2        Liverpool   92         NaN  38  28   8   2  94  26   68
# 2  3          Chelsea   74         NaN  38  21  11   6  76  33   43
# 3  4        Tottenham   71         NaN  38  22   5  11  69  40   29

# %% [markdown]
# Calcular as medidas de centralidade e dispersão

# %% [markdown]
# Fazer os gráficos de bloxplot

# %% [markdown]
# #--------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # DataFrame Classificados PL

# %%
df_classificados = df_classPL1213.append([df_classPL1314, df_classPL1415, df_classPL1516, df_classPL1617, df_classPL1718,
                                          df_classPL1819, df_classPL1920, df_classPL2021, df_classPL2122])

# %%
df_classificados.drop(["Unnamed: 3"], axis = 1, inplace = True)

# %%
df_classificados.rename(columns={"+" : "gm"}, inplace = True)

# %%
df_classificados.rename(columns={"-" : "gs"}, inplace = True)

# %%
df_classificados.rename(columns={"+/-" : "sg"}, inplace = True)

# %%
df_classificados
# Out:
#    #             Time  pts   j   v   e   d   gm  gs  sg
# 0  1   Manchester Utd   89  38  28   5   5   86  43  43
# 1  2  Manchester City   78  38  23   9   6   66  34  32
# 2  3          Chelsea   75  38  22   9   7   75  39  36
# 3  4          Arsenal   73  38  21  10   7   72  37  35
# 0  1  Manchester City   86  38  27   5   6  102  37  65
# 1  2        Liverpool   84  38  26   6   6  101  50  51
# 2  3          Chelsea   82  38  25   7   6   71  27  44
# 3  4          Arsenal   79  38  24   7   7   68  41  27
# 0  1          Chelsea   87  38  26   9   3   73  32  41
# 1  2  Manchester City   79  38  24   7   7   83  38  45
# 2  3          Arsenal   75  38  22   9   7   71  36  35
# 3  4   Manchester Utd   70  38  20  10   8   62  37  25
# 0  1        Leicester   81  38  23  12   3   68  36  32
# 1  2          Arsenal   71  38  20  11   7   65  36  29
# 2  3        Tottenham   70  38  19  13   6   69  35  34
# 3  4  Manchester City   66  38  19   9  10   71  41  30
# ...

# %% [markdown]
# # DataFrame Primeiros Colocados PL

# %%
mask1 = df_classificados["#"] == 1

# %%
df_primeiros = df_classificados[mask1]

# %%
df_primeiros.drop(["#"], axis = 1, inplace = True)
# Out:
# C:\Users\bergs\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_primeiros.insert(0, "Pos", ["1º", "1º", "1º", "1º", "1º", "1º", "1º", "1º", "1º", "1º"], True)

# %%
df_primeiros.insert(1, "Temporada", ["--12/13--", "--13/14--", "--14/15--", "--15/16--", "--16/17--", "--17/18--", "--18/19--",
                                     "--19/20--", "--20/21--", "--21/22--"], True)

# %%
df_primeiros
# Out:
#   Pos  Temporada             Time  pts   j   v   e  d   gm  gs  sg
# 0  1º  --12/13--   Manchester Utd   89  38  28   5  5   86  43  43
# 0  1º  --13/14--  Manchester City   86  38  27   5  6  102  37  65
# 0  1º  --14/15--          Chelsea   87  38  26   9  3   73  32  41
# 0  1º  --15/16--        Leicester   81  38  23  12  3   68  36  32
# 0  1º  --16/17--          Chelsea   93  38  30   3  5   85  33  52
# 0  1º  --17/18--  Manchester City  100  38  32   4  2  106  27  79
# 0  1º  --18/19--  Manchester City   98  38  32   2  4   95  23  72
# 0  1º  --19/20--        Liverpool   99  38  32   3  3   85  33  52
# 0  1º  --20/21--  Manchester City   86  38  27   5  6   83  32  51
# 0  1º  --21/22--  Manchester City   93  38  29   6  3   99  26  73

# %% [markdown]
# # DataFrame Segundos Colocados PL

# %%
mask2 = df_classificados["#"] == 2

# %%
df_segundos = df_classificados[mask2]

# %%
df_segundos.drop(["#"], axis = 1, inplace = True)

# %%
df_segundos.insert(0, "Pos", ["2º", "2º", "2º", "2º", "2º", "2º", "2º", "2º", "2º", "2º"], True)

# %%
df_segundos.insert(1, "Temporada", ["--12/13--", "--13/14--", "--14/15--", "--15/16--", "--16/17--", "--17/18--", "--18/19--",
                                     "--19/20--", "--20/21--", "--21/22--"], True)

# %%
df_segundos
# Out:
#   Pos  Temporada             Time  pts   j   v   e  d   gm  gs  sg
# 1  2º  --12/13--  Manchester City   78  38  23   9  6   66  34  32
# 1  2º  --13/14--        Liverpool   84  38  26   6  6  101  50  51
# 1  2º  --14/15--  Manchester City   79  38  24   7  7   83  38  45
# 1  2º  --15/16--          Arsenal   71  38  20  11  7   65  36  29
# 1  2º  --16/17--        Tottenham   86  38  26   8  4   86  26  60
# 1  2º  --17/18--   Manchester Utd   81  38  25   6  7   68  28  40
# 1  2º  --18/19--        Liverpool   97  38  30   7  1   89  22  67
# 1  2º  --19/20--  Manchester City   81  38  26   3  9  102  35  67
# 1  2º  --20/21--   Manchester Utd   74  38  21  11  6   73  44  29
# 1  2º  --21/22--        Liverpool   92  38  28   8  2   94  26  68

# %% [markdown]
# # DataFrame Terceiros Colocados PL

# %%
mask3 = df_classificados["#"] == 3

# %%
df_terceiros = df_classificados[mask3]

# %%
df_terceiros.drop(["#"], axis = 1, inplace = True)

# %%
df_terceiros.insert(0, "Pos", ["3º", "3º", "3º", "3º", "3º", "3º", "3º", "3º", "3º", "3º"], True)

# %%
df_terceiros.insert(1, "Temporada", ["--12/13--", "--13/14--", "--14/15--", "--15/16--", "--16/17--", "--17/18--", "--18/19--",
                                     "--19/20--", "--20/21--", "--21/22--"], True)

# %%
df_terceiros
# Out:
#   Pos  Temporada             Time  pts   j   v   e  d  gm  gs  sg
# 2  3º  --12/13--          Chelsea   75  38  22   9  7  75  39  36
# 2  3º  --13/14--          Chelsea   82  38  25   7  6  71  27  44
# 2  3º  --14/15--          Arsenal   75  38  22   9  7  71  36  35
# 2  3º  --15/16--        Tottenham   70  38  19  13  6  69  35  34
# 2  3º  --16/17--  Manchester City   78  38  23   9  6  80  39  41
# 2  3º  --17/18--        Tottenham   77  38  23   8  7  74  36  38
# 2  3º  --18/19--          Chelsea   72  38  21   9  8  63  39  24
# 2  3º  --19/20--   Manchester Utd   66  38  18  12  8  66  36  30
# 2  3º  --20/21--        Liverpool   69  38  20   9  9  68  42  26
# 2  3º  --21/22--          Chelsea   74  38  21  11  6  76  33  43

# %% [markdown]
# # DataFrame Quartos Colocados PL

# %%
mask4 = df_classificados["#"] == 4

# %%
df_quartos = df_classificados[mask4]

# %%
df_quartos.drop(["#"], axis = 1, inplace = True)

# %%
df_quartos.insert(0, "Pos", ["4º", "4º", "4º", "4º", "4º", "4º", "4º", "4º", "4º", "4º"], True)

# %%
df_quartos.insert(1, "Temporada", ["--12/13--", "--13/14--", "--14/15--", "--15/16--", "--16/17--", "--17/18--", "--18/19--",
                                     "--19/20--", "--20/21--", "--21/22--"], True)

# %%
df_quartos
# Out:
#   Pos  Temporada             Time  pts   j   v   e   d  gm  gs  sg
# 3  4º  --12/13--          Arsenal   73  38  21  10   7  72  37  35
# 3  4º  --13/14--          Arsenal   79  38  24   7   7  68  41  27
# 3  4º  --14/15--   Manchester Utd   70  38  20  10   8  62  37  25
# 3  4º  --15/16--  Manchester City   66  38  19   9  10  71  41  30
# 3  4º  --16/17--        Liverpool   76  38  22  10   6  78  42  36
# 3  4º  --17/18--        Liverpool   75  38  21  12   5  84  38  46
# 3  4º  --18/19--        Tottenham   71  38  23   2  13  67  39  28
# 3  4º  --19/20--          Chelsea   66  38  20   6  12  69  54  15
# 3  4º  --20/21--          Chelsea   67  38  19  10   9  58  36  22
# 3  4º  --21/22--        Tottenham   71  38  22   5  11  69  40  29

# %% [markdown]
# # Análise sobre os primeiros colocados

# %%
df_primeiros
# Out:
#   Pos  Temporada             Time  pts   j   v   e  d   gm  gs  sg
# 0  1º  --12/13--   Manchester Utd   89  38  28   5  5   86  43  43
# 0  1º  --13/14--  Manchester City   86  38  27   5  6  102  37  65
# 0  1º  --14/15--          Chelsea   87  38  26   9  3   73  32  41
# 0  1º  --15/16--        Leicester   81  38  23  12  3   68  36  32
# 0  1º  --16/17--          Chelsea   93  38  30   3  5   85  33  52
# 0  1º  --17/18--  Manchester City  100  38  32   4  2  106  27  79
# 0  1º  --18/19--  Manchester City   98  38  32   2  4   95  23  72
# 0  1º  --19/20--        Liverpool   99  38  32   3  3   85  33  52
# 0  1º  --20/21--  Manchester City   86  38  27   5  6   83  32  51
# 0  1º  --21/22--  Manchester City   93  38  29   6  3   99  26  73

# %% [markdown]
# Análise sobre os pontos

# %%
media_pts1 = df_primeiros["pts"].mean()
mediana_pts1 = df_primeiros["pts"].median()
moda_pts1 = df_primeiros["pts"].mode()
var_pts1 = np.var(df_primeiros["pts"])
desv_pts1 = np.std(df_primeiros["pts"])

# %%
media_pts1, mediana_pts1, moda_pts1, var_pts1, desv_pts1
# Out:
# (91.2,
#  91.0,
#  0    86
#  1    93
#  dtype: int64,
#  37.160000000000004,
#  6.095900261651268)

# %% [markdown]
# //////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de vitórias

# %%
media_v1 = df_primeiros["v"].mean()
mediana_v1 = df_primeiros["v"].median()
moda_v1 = df_primeiros["v"].mode()
var_v1 = np.var(df_primeiros["v"])
desv_v1 = np.std(df_primeiros["v"])

# %%
media_v1, mediana_v1, moda_v1, var_v1, desv_v1
# Out:
# (28.6,
#  28.5,
#  0    32
#  dtype: int64,
#  8.04,
#  2.835489375751565)

# %% [markdown]
# ////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de empates

# %%
media_e1 = df_primeiros["e"].mean()
mediana_e1 = df_primeiros["e"].median()
moda_e1 = df_primeiros["e"].mode()
var_e1 = np.var(df_primeiros["e"])
desv_e1 = np.std(df_primeiros["e"])

# %%
media_e1, mediana_e1, moda_e1, var_e1, desv_e1
# Out:
# (5.4,
#  5.0,
#  0    5
#  dtype: int64,
#  8.24,
#  2.870540018881465)

# %% [markdown]
# ////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de derrotas

# %%
media_d1 = df_primeiros["d"].mean()
mediana_d1 = df_primeiros["d"].median()
moda_d1 = df_primeiros["d"].mode()
var_d1 = np.var(df_primeiros["d"])
desv_d1 = np.std(df_primeiros["d"])

# %%
media_d1, mediana_d1, moda_d1, var_d1, desv_d1
# Out:
# (4.0,
#  3.5,
#  0    3
#  dtype: int64,
#  1.8,
#  1.3416407864998738)

# %% [markdown]
# /////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre os gols marcados

# %%
media_gm1 = df_primeiros["gm"].mean()
mediana_gm1 = df_primeiros["gm"].median()
moda_gm1 = df_primeiros["gm"].mode()
var_gm1 = np.var(df_primeiros["gm"])
desv_gm1 = np.std(df_primeiros["gm"])

# %%
media_gm1, mediana_gm1, moda_gm1, var_gm1, desv_gm1
# Out:
# (88.2,
#  85.5,
#  0    85
#  dtype: int64,
#  136.16,
#  11.668761716651858)

# %% [markdown]
# /////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre os gols sofridos

# %%
media_gs1 = df_primeiros["gs"].mean()
mediana_gs1 = df_primeiros["gs"].median()
moda_gs1 = df_primeiros["gs"].mode()
var_gs1 = np.var(df_primeiros["gs"])
desv_gs1 = np.std(df_primeiros["gs"])

# %%
media_gs1, mediana_gs1, moda_gs1, var_gs1, desv_gs1
# Out:
# (32.2,
#  32.5,
#  0    32
#  1    33
#  dtype: int64,
#  30.560000000000002,
#  5.528109984434102)

# %% [markdown]
# /////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o saldo de gols

# %%
media_sg1 = df_primeiros["sg"].mean()
mediana_sg1 = df_primeiros["sg"].median()
moda_sg1 = df_primeiros["sg"].mode()
var_sg1 = np.var(df_primeiros["sg"])
desv_sg1 = np.std(df_primeiros["sg"])

# %%
media_sg1, mediana_sg1, moda_sg1, var_sg1, desv_sg1
# Out:
# (56.0,
#  52.0,
#  0    52
#  dtype: int64,
#  218.2,
#  14.771594362153328)

# %% [markdown]
# # Boxplots primeiros colocados

# %%
bp_pts1 = df_primeiros.boxplot(column = ["pts"])

# %%
bp_v1 = df_primeiros.boxplot(column = ["v"])

# %%
bp_e1 = df_primeiros.boxplot(column = ["e"])

# %%
bp_d1 = df_primeiros.boxplot(column = ["d"])

# %%
bp_gm1 = df_primeiros.boxplot(column = ["gm"])

# %%
bp_gs1 = df_primeiros.boxplot(column = ["gs"])

# %%
bp_sg1 = df_primeiros.boxplot(column = ["sg"])

# %% [markdown]
# # Análise sobre os segundos colocados

# %%
df_segundos
# Out:
#   Pos  Temporada             Time  pts   j   v   e  d   gm  gs  sg
# 1  2º  --12/13--  Manchester City   78  38  23   9  6   66  34  32
# 1  2º  --13/14--        Liverpool   84  38  26   6  6  101  50  51
# 1  2º  --14/15--  Manchester City   79  38  24   7  7   83  38  45
# 1  2º  --15/16--          Arsenal   71  38  20  11  7   65  36  29
# 1  2º  --16/17--        Tottenham   86  38  26   8  4   86  26  60
# 1  2º  --17/18--   Manchester Utd   81  38  25   6  7   68  28  40
# 1  2º  --18/19--        Liverpool   97  38  30   7  1   89  22  67
# 1  2º  --19/20--  Manchester City   81  38  26   3  9  102  35  67
# 1  2º  --20/21--   Manchester Utd   74  38  21  11  6   73  44  29
# 1  2º  --21/22--        Liverpool   92  38  28   8  2   94  26  68

# %% [markdown]
# Análise sobre os pontos

# %%
media_pts2 = df_segundos["pts"].mean()
mediana_pts2 = df_segundos["pts"].median()
moda_pts2 = df_segundos["pts"].mode()
var_pts2 = np.var(df_segundos["pts"])
desv_pts2 = np.std(df_segundos["pts"])

# %%
media_pts2, mediana_pts2, moda_pts2, var_pts2, desv_pts2
# Out:
# (82.3,
#  81.0,
#  0    81
#  dtype: int64,
#  55.61,
#  7.457211275000863)

# %% [markdown]
# ///////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de vitórias

# %%
media_v2 = df_segundos["v"].mean()
mediana_v2 = df_segundos["v"].median()
moda_v2 = df_segundos["v"].mode()
var_v2 = np.var(df_segundos["v"])
desv_v2 = np.std(df_segundos["v"])

# %%
media_v2, mediana_v2, moda_v2, var_v2, desv_v2
# Out:
# (24.9,
#  25.5,
#  0    26
#  dtype: int64,
#  8.290000000000001,
#  2.879236009777594)

# %% [markdown]
# //////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de empates

# %%
media_e2 = df_segundos["e"].mean()
mediana_e2 = df_segundos["e"].median()
moda_e2 = df_segundos["e"].mode()
var_e2 = np.var(df_segundos["e"])
desv_e2 = np.std(df_segundos["e"])

# %%
media_e2, mediana_e2, moda_e2, var_e2, desv_e2
# Out:
# (7.6,
#  7.5,
#  0     6
#  1     7
#  2     8
#  3    11
#  dtype: int64,
#  5.24,
#  2.2891046284519194)

# %% [markdown]
# //////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de derrotas

# %%
media_d2 = df_segundos["d"].mean()
mediana_d2 = df_segundos["d"].median()
moda_d2 = df_segundos["d"].mode()
var_d2 = np.var(df_segundos["d"])
desv_d2 = np.std(df_segundos["d"])

# %%
media_d2, mediana_d2, moda_d2, var_d2, desv_d2
# Out:
# (5.5,
#  6.0,
#  0    6
#  1    7
#  dtype: int64,
#  5.45,
#  2.3345235059857505)

# %% [markdown]
# ////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre os gols marcados

# %%
media_gm2 = df_segundos["gm"].mean()
mediana_gm2 = df_segundos["gm"].median()
moda_gm2 = df_segundos["gm"].mode()
var_gm2 = np.var(df_segundos["gm"])
desv_gm2 = np.std(df_segundos["gm"])

# %%
media_gm2, mediana_gm2, moda_gm2, var_gm2, desv_gm2
# Out:
# (82.7,
#  84.5,
#  0     65
#  1     66
#  2     68
#  3     73
#  4     83
#  5     86
#  6     89
#  7     94
#  8    101
#  9    102
#  dtype: int64,
#  178.81000000000003,
#  13.37198564163154)

# %% [markdown]
# ///////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre os gols sofridos

# %%
media_gs2 = df_segundos["gs"].mean()
mediana_gs2 = df_segundos["gs"].median()
moda_gs2 = df_segundos["gs"].mode()
var_gs2 = np.var(df_segundos["gs"])
desv_gs2 = np.std(df_segundos["gs"])

# %%
media_gs2, mediana_gs2, moda_gs2, var_gs2, desv_gs2
# Out:
# (33.9,
#  34.5,
#  0    26
#  dtype: int64,
#  68.49,
#  8.275868534480233)

# %% [markdown]
# ///////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o saldo de gols

# %%
media_sg2 = df_segundos["sg"].mean()
mediana_sg2 = df_segundos["sg"].median()
moda_sg2 = df_segundos["sg"].mode()
var_sg2 = np.var(df_segundos["sg"])
desv_sg2 = np.std(df_segundos["sg"])

# %%
media_sg2, mediana_sg2, moda_sg2, var_sg2, desv_sg2
# Out:
# (48.8,
#  48.0,
#  0    29
#  1    67
#  dtype: int64,
#  231.96000000000004,
#  15.230233090796741)

# %% [markdown]
# # Boxplots segundos colocados

# %%
bp_pts2 = df_segundos.boxplot(column = ["pts"])

# %%
bp_v2 = df_segundos.boxplot(column = ["v"])

# %%
bp_e2 = df_segundos.boxplot(column = ["e"])

# %%
bp_d2 = df_segundos.boxplot(column = ["d"])

# %%
bp_gm2 = df_segundos.boxplot(column = ["gm"])

# %%
bp_gs2 = df_segundos.boxplot(column = ["gs"])

# %%
bp_sg2 = df_segundos.boxplot(column = ["sg"])

# %% [markdown]
# # Análise sobre os terceiros colocados

# %%
df_terceiros
# Out:
#   Pos  Temporada             Time  pts   j   v   e  d  gm  gs  sg
# 2  3º  --12/13--          Chelsea   75  38  22   9  7  75  39  36
# 2  3º  --13/14--          Chelsea   82  38  25   7  6  71  27  44
# 2  3º  --14/15--          Arsenal   75  38  22   9  7  71  36  35
# 2  3º  --15/16--        Tottenham   70  38  19  13  6  69  35  34
# 2  3º  --16/17--  Manchester City   78  38  23   9  6  80  39  41
# 2  3º  --17/18--        Tottenham   77  38  23   8  7  74  36  38
# 2  3º  --18/19--          Chelsea   72  38  21   9  8  63  39  24
# 2  3º  --19/20--   Manchester Utd   66  38  18  12  8  66  36  30
# 2  3º  --20/21--        Liverpool   69  38  20   9  9  68  42  26
# 2  3º  --21/22--          Chelsea   74  38  21  11  6  76  33  43

# %% [markdown]
# Análise sobre os pontos

# %%
media_pts3 = df_terceiros["pts"].mean()
mediana_pts3 = df_terceiros["pts"].median()
moda_pts3 = df_terceiros["pts"].mode()
var_pts3 = np.var(df_terceiros["pts"])
desv_pts3 = np.std(df_terceiros["pts"])

# %%
media_pts3, mediana_pts3, moda_pts3, var_pts3, desv_pts3
# Out:
# (73.8,
#  74.5,
#  0    75
#  dtype: int64,
#  19.96,
#  4.467661580737736)

# %% [markdown]
# /////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de vitórias

# %%
media_v3 = df_terceiros["v"].mean()
mediana_v3 = df_terceiros["v"].median()
moda_v3 = df_terceiros["v"].mode()
var_v3 = np.var(df_terceiros["v"])
desv_v3 = np.std(df_terceiros["v"])

# %%
media_v3, mediana_v3, moda_v3, var_v3, desv_v3
# Out:
# (21.4,
#  21.5,
#  0    21
#  1    22
#  2    23
#  dtype: int64,
#  3.84,
#  1.9595917942265424)

# %% [markdown]
# /////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de empates

# %%
media_e3 = df_terceiros["e"].mean()
mediana_e3 = df_terceiros["e"].median()
moda_e3 = df_terceiros["e"].mode()
var_e3 = np.var(df_terceiros["e"])
desv_e3 = np.std(df_terceiros["e"])

# %%
media_e3, mediana_e3, moda_e3, var_e3, desv_e3
# Out:
# (9.6,
#  9.0,
#  0    9
#  dtype: int64,
#  3.04,
#  1.7435595774162693)

# %% [markdown]
# ///////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de derrotas

# %%
media_d3 = df_terceiros["d"].mean()
mediana_d3 = df_terceiros["d"].median()
moda_d3 = df_terceiros["d"].mode()
var_d3 = np.var(df_terceiros["d"])
desv_d3 = np.std(df_terceiros["d"])

# %%
media_d3, mediana_d3, moda_d3, var_d3, desv_d3
# Out:
# (7.0,
#  7.0,
#  0    6
#  dtype: int64,
#  1.0,
#  1.0)

# %% [markdown]
# ///////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre os gols marcados

# %%
media_gm3 = df_terceiros["gm"].mean()
mediana_gm3 = df_terceiros["gm"].median()
moda_gm3 = df_terceiros["gm"].mode()
var_gm3 = np.var(df_terceiros["gm"])
desv_gm3 = np.std(df_terceiros["gm"])

# %%
media_gm3, mediana_gm3, moda_gm3, var_gm3, desv_gm3
# Out:
# (71.3,
#  71.0,
#  0    71
#  dtype: int64,
#  23.21,
#  4.817675788178362)

# %% [markdown]
# ///////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre os gols sofridos

# %%
media_gs3 = df_terceiros["gs"].mean()
mediana_gs3 = df_terceiros["gs"].median()
moda_gs3 = df_terceiros["gs"].mode()
var_gs3 = np.var(df_terceiros["gs"])
desv_gs3 = np.std(df_terceiros["gs"])

# %%
media_gs3, mediana_gs3, moda_gs3, var_gs3, desv_gs3
# Out:
# (36.2,
#  36.0,
#  0    36
#  1    39
#  dtype: int64,
#  15.360000000000003,
#  3.9191835884530852)

# %% [markdown]
# //////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o saldo de gols

# %%
media_sg3 = df_terceiros["sg"].mean()
mediana_sg3 = df_terceiros["sg"].median()
moda_sg3 = df_terceiros["sg"].mode()
var_sg3 = np.var(df_terceiros["sg"])
desv_sg3 = np.std(df_terceiros["sg"])

# %%
media_sg3, mediana_sg3, moda_sg3, var_sg3, desv_sg3
# Out:
# (35.1,
#  35.5,
#  0    24
#  1    26
#  2    30
#  3    34
#  4    35
#  5    36
#  6    38
#  7    41
#  8    43
#  9    44
#  dtype: int64,
#  41.89,
#  6.472248450113763)

# %% [markdown]
# # Boxplots terceiros colocados

# %%
bp_pts3 = df_terceiros.boxplot(column = ["pts"])

# %%
bp_v3 = df_terceiros.boxplot(column = ["v"])

# %%
bp_e3 = df_terceiros.boxplot(column = ["e"])

# %%
bp_d3 = df_terceiros.boxplot(column = ["d"])

# %%
bp_gm3 = df_terceiros.boxplot(column = ["gm"])

# %%
bp_gs3 = df_terceiros.boxplot(column = ["gs"])

# %%
bp_sg3 = df_terceiros.boxplot(column = ["sg"])

# %% [markdown]
# # Análise sobre os quartos colocados

# %%
df_quartos
# Out:
#   Pos  Temporada             Time  pts   j   v   e   d  gm  gs  sg
# 3  4º  --12/13--          Arsenal   73  38  21  10   7  72  37  35
# 3  4º  --13/14--          Arsenal   79  38  24   7   7  68  41  27
# 3  4º  --14/15--   Manchester Utd   70  38  20  10   8  62  37  25
# 3  4º  --15/16--  Manchester City   66  38  19   9  10  71  41  30
# 3  4º  --16/17--        Liverpool   76  38  22  10   6  78  42  36
# 3  4º  --17/18--        Liverpool   75  38  21  12   5  84  38  46
# 3  4º  --18/19--        Tottenham   71  38  23   2  13  67  39  28
# 3  4º  --19/20--          Chelsea   66  38  20   6  12  69  54  15
# 3  4º  --20/21--          Chelsea   67  38  19  10   9  58  36  22
# 3  4º  --21/22--        Tottenham   71  38  22   5  11  69  40  29

# %% [markdown]
# Análise sobre os pontos

# %%
media_pts4 = df_quartos["pts"].mean()
mediana_pts4 = df_quartos["pts"].median()
moda_pts4 = df_quartos["pts"].mode()
var_pts4 = np.var(df_quartos["pts"])
desv_pts4 = np.std(df_quartos["pts"])

# %%
media_pts4, mediana_pts4, moda_pts4, var_pts4, desv_pts4
# Out:
# (71.4,
#  71.0,
#  0    66
#  1    71
#  dtype: int64,
#  17.439999999999998,
#  4.176122603564219)

# %% [markdown]
# /////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de vitórias

# %%
media_v4 = df_quartos["v"].mean()
mediana_v4 = df_quartos["v"].median()
moda_v4 = df_quartos["v"].mode()
var_v4 = np.var(df_quartos["v"])
desv_v4 = np.std(df_quartos["v"])

# %%
media_v4, mediana_v4, moda_v4, var_v4, desv_v4
# Out:
# (21.1,
#  21.0,
#  0    19
#  1    20
#  2    21
#  3    22
#  dtype: int64,
#  2.49,
#  1.57797338380595)

# %% [markdown]
# ///////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de empates

# %%
media_e4 = df_quartos["e"].mean()
mediana_e4 = df_quartos["e"].median()
moda_e4 = df_quartos["e"].mode()
var_e4 = np.var(df_quartos["e"])
desv_e4 = np.std(df_quartos["e"])

# %%
media_e4, mediana_e4, moda_e4, var_e4, desv_e4
# Out:
# (8.1,
#  9.5,
#  0    10
#  dtype: int64,
#  8.29,
#  2.8792360097775935)

# %% [markdown]
# //////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o número de derrotas

# %%
media_d4 = df_quartos["d"].mean()
mediana_d4 = df_quartos["d"].median()
moda_d4 = df_quartos["d"].mode()
var_d4 = np.var(df_quartos["d"])
desv_d4 = np.std(df_quartos["d"])

# %%
media_d4, mediana_d4, moda_d4, var_d4, desv_d4
# Out:
# (8.8,
#  8.5,
#  0    7
#  dtype: int64,
#  6.359999999999999,
#  2.521904042583698)

# %% [markdown]
# //////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre os gols marcados

# %%
media_gm4 = df_quartos["gm"].mean()
mediana_gm4 = df_quartos["gm"].median()
moda_gm4 = df_quartos["gm"].mode()
var_gm4 = np.var(df_quartos["gm"])
desv_gm4 = np.std(df_quartos["gm"])

# %%
media_gm4, mediana_gm4, moda_gm4, var_gm4, desv_gm4
# Out:
# (69.8,
#  69.0,
#  0    69
#  dtype: int64,
#  48.760000000000005,
#  6.982836100038437)

# %% [markdown]
# ////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre os gols sofridos

# %%
media_gs4 = df_quartos["gs"].mean()
mediana_gs4 = df_quartos["gs"].median()
moda_gs4 = df_quartos["gs"].mode()
var_gs4 = np.var(df_quartos["gs"])
desv_gs4 = np.std(df_quartos["gs"])

# %%
media_gs4, mediana_gs4, moda_gs4, var_gs4, desv_gs4
# Out:
# (40.5,
#  39.5,
#  0    37
#  1    41
#  dtype: int64,
#  23.85,
#  4.883646178829912)

# %% [markdown]
# /////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# Análise sobre o saldo de gols

# %%
media_sg4 = df_quartos["sg"].mean()
mediana_sg4 = df_quartos["sg"].median()
moda_sg4 = df_quartos["sg"].mode()
var_sg4 = np.var(df_quartos["sg"])
desv_sg4 = np.std(df_quartos["sg"])

# %%
media_sg4, mediana_sg4, moda_sg4, var_sg4, desv_sg4
# Out:
# (29.3,
#  28.5,
#  0    15
#  1    22
#  2    25
#  3    27
#  4    28
#  5    29
#  6    30
#  7    35
#  8    36
#  9    46
#  dtype: int64,
#  64.01,
#  8.000624975587845)

# %% [markdown]
# # Boxplots quartos colocados

# %%
bp_pts4 = df_quartos.boxplot(column = ["pts"])

# %%
bp_v4 = df_quartos.boxplot(column = ["v"])

# %%
bp_e4 = df_quartos.boxplot(column = ["e"])

# %%
bp_d4 = df_quartos.boxplot(column = ["d"])

# %%
bp_gm4 = df_quartos.boxplot(column = ["gm"])

# %%
bp_gs4 = df_quartos.boxplot(column = ["gs"])

# %%
bp_sg4 = df_quartos.boxplot(column = ["sg"])

# %% [markdown]
# # Analisando quais times não foram campeões mas tiveram o aproveitamento de um campeão

# %%
df_cl = df_segundos.append([df_terceiros, df_quartos])

# %%
df_cl
# Out:
#   Pos  Temporada             Time  pts   j   v   e   d   gm  gs  sg
# 1  2º  --12/13--  Manchester City   78  38  23   9   6   66  34  32
# 1  2º  --13/14--        Liverpool   84  38  26   6   6  101  50  51
# 1  2º  --14/15--  Manchester City   79  38  24   7   7   83  38  45
# 1  2º  --15/16--          Arsenal   71  38  20  11   7   65  36  29
# 1  2º  --16/17--        Tottenham   86  38  26   8   4   86  26  60
# 1  2º  --17/18--   Manchester Utd   81  38  25   6   7   68  28  40
# 1  2º  --18/19--        Liverpool   97  38  30   7   1   89  22  67
# 1  2º  --19/20--  Manchester City   81  38  26   3   9  102  35  67
# 1  2º  --20/21--   Manchester Utd   74  38  21  11   6   73  44  29
# 1  2º  --21/22--        Liverpool   92  38  28   8   2   94  26  68
# 2  3º  --12/13--          Chelsea   75  38  22   9   7   75  39  36
# 2  3º  --13/14--          Chelsea   82  38  25   7   6   71  27  44
# 2  3º  --14/15--          Arsenal   75  38  22   9   7   71  36  35
# ...

# %%
df_destaquespts = df_cl[df_cl["pts"] >= media_pts1 - desv_pts1] # Quais times alcançaram a pontuação média de um campeão - desvio padrão.

# %%
df_destaquespts
# Out:
#   Pos  Temporada       Time  pts   j   v  e  d  gm  gs  sg
# 1  2º  --16/17--  Tottenham   86  38  26  8  4  86  26  60
# 1  2º  --18/19--  Liverpool   97  38  30  7  1  89  22  67
# 1  2º  --21/22--  Liverpool   92  38  28  8  2  94  26  68

# %%
df_destaquesv = df_cl[df_cl["v"] >= media_v1 - desv_v1]

# %%
df_destaquesv
# Out:
#   Pos  Temporada             Time  pts   j   v  e  d   gm  gs  sg
# 1  2º  --13/14--        Liverpool   84  38  26  6  6  101  50  51
# 1  2º  --16/17--        Tottenham   86  38  26  8  4   86  26  60
# 1  2º  --18/19--        Liverpool   97  38  30  7  1   89  22  67
# 1  2º  --19/20--  Manchester City   81  38  26  3  9  102  35  67
# 1  2º  --21/22--        Liverpool   92  38  28  8  2   94  26  68

# %%
df_destaquesd = df_cl[df_cl["d"] <= media_d1 + desv_d1]

# %%
df_destaquesd
# Out:
#   Pos  Temporada       Time  pts   j   v   e  d  gm  gs  sg
# 1  2º  --16/17--  Tottenham   86  38  26   8  4  86  26  60
# 1  2º  --18/19--  Liverpool   97  38  30   7  1  89  22  67
# 1  2º  --21/22--  Liverpool   92  38  28   8  2  94  26  68
# 3  4º  --17/18--  Liverpool   75  38  21  12  5  84  38  46

# %%
df_primeiros
# Out:
#   Pos  Temporada             Time  pts   j   v   e  d   gm  gs  sg
# 0  1º  --12/13--   Manchester Utd   89  38  28   5  5   86  43  43
# 0  1º  --13/14--  Manchester City   86  38  27   5  6  102  37  65
# 0  1º  --14/15--          Chelsea   87  38  26   9  3   73  32  41
# 0  1º  --15/16--        Leicester   81  38  23  12  3   68  36  32
# 0  1º  --16/17--          Chelsea   93  38  30   3  5   85  33  52
# 0  1º  --17/18--  Manchester City  100  38  32   4  2  106  27  79
# 0  1º  --18/19--  Manchester City   98  38  32   2  4   95  23  72
# 0  1º  --19/20--        Liverpool   99  38  32   3  3   85  33  52
# 0  1º  --20/21--  Manchester City   86  38  27   5  6   83  32  51
# 0  1º  --21/22--  Manchester City   93  38  29   6  3   99  26  73

# %% [markdown]
# # Champions league

# %% [markdown]
# Analisar a partir da champions 13/14 (sempre um ano a frente das ligas)

# %% [markdown]
# # Champions League 13/14

# %%
CL1314 = [
    {"PL" : "1º",
    "Temporada" : "--13/14--",
    "Time" : "Manchester Utd",
    "Pos FG" : "1º",
    "PTS" : "14",
    "J" : "6",
    "V" : "4",
    "E" : "2",
    "D" : "0",
    "||" : "",
    "Pos MM" : "5º - 8º",
    "JM" : "4",
    "VM" : "1",
    "EM" : "1",
    "DM" : "2",
    "GP" : "17",
    "GC" : "9",
    "SG" : "8"},
    
    {"PL" : "2º",
    "Temporada" : "--13/14--",
    "Time" : "Manchester City",
    "Pos FG" : "2º",
    "PTS" : "15",
    "J" : "6",
    "V" : "5",
    "E" : "0",
    "D" : "1",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "0",
    "DM" : "2",
    "GP" : "19",
    "GC" : "14",
    "SG" : "5"},
    
    {"PL" : "3º",
    "Temporada" : "--13/14--",
    "Time" : "Chelsea",
    "Pos FG" : "1º",
    "PTS" : "12",
    "J" : "6",
    "V" : "4",
    "E" : "0",
    "D" : "2",
    "||" : "",
    "Pos MM" : "3º - 4º",
    "JM" : "6",
    "VM" : "2",
    "EM" : "2",
    "DM" : "2",
    "GP" : "19",
    "GC" : "10",
    "SG" : "9"},
    
    {"PL" : "4º",
    "Temporada" : "--13/14--",
    "Time" : "Arsenal",
    "Pos FG" : "2º",
    "PTS" : "12",
    "J" : "6",
    "V" : "4",
    "E" : "0",
    "D" : "2",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "1",
    "DM" : "1",
    "GP" : "9",
    "GC" : "8",
    "SG" : "1"}
]

# %%
df_CL1314 = pd.DataFrame(CL1314)

# %%
df_CL1314
# Out:
#    PL  Temporada             Time Pos FG PTS  J  V  E  D ||    Pos MM JM VM  \
# 0  1º  --13/14--   Manchester Utd     1º  14  6  4  2  0      5º - 8º  4  1
# 1  2º  --13/14--  Manchester City     2º  15  6  5  0  1     9º - 16º  2  0
# 2  3º  --13/14--          Chelsea     1º  12  6  4  0  2      3º - 4º  6  2
# 3  4º  --13/14--          Arsenal     2º  12  6  4  0  2     9º - 16º  2  0
#
#   EM DM  GP  GC SG
# 0  1  2  17   9  8
# 1  0  2  19  14  5
# 2  2  2  19  10  9
# 3  1  1   9   8  1

# %% [markdown]
# # Champions League 14/15

# %%
CL1415 = [
    {"PL" : "1º",
    "Temporada" : "--14/15--",
    "Time" : "Manchester City",
    "Pos FG" : "2º",
    "PTS" : "9",
    "J" : "6",
    "V" : "2",
    "E" : "2",
    "D" : "2",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "0",
    "DM" : "2",
    "GP" : "10",
    "GC" : "11",
    "SG" : "-1"},
    
    {"PL" : "2º",
    "Temporada" : "--14/15--",
    "Time" : "Liverpool",
    "Pos FG" : "3º",
    "PTS" : "5",
    "J" : "6",
    "V" : "1",
    "E" : "2",
    "D" : "3",
    "||" : "",
    "Pos MM" : "",
    "JM" : "",
    "VM" : "",
    "EM" : "",
    "DM" : "",
    "GP" : "5",
    "GC" : "9",
    "SG" : "-4"},
    
    {"PL" : "3º",
    "Temporada" : "--14/15--",
    "Time" : "Chelsea",
    "Pos FG" : "1º",
    "PTS" : "14",
    "J" : "6",
    "V" : "4",
    "E" : "2",
    "D" : "0",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "2",
    "DM" : "0",
    "GP" : "20",
    "GC" : "6",
    "SG" : "14"},
    
    {"PL" : "4º",
    "Temporada" : "--14/15--",
    "Time" : "Arsenal",
    "Pos FG" : "2º",
    "PTS" : "13",
    "J" : "6",
    "V" : "4",
    "E" : "1",
    "D" : "1",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "1",
    "EM" : "0",
    "DM" : "1",
    "GP" : "18",
    "GC" : "11",
    "SG" : "7"}
]

# %%
df_CL1415 = pd.DataFrame(CL1415)

# %%
df_CL1415
# Out:
#    PL  Temporada             Time Pos FG PTS  J  V  E  D ||    Pos MM JM VM  \
# 0  1º  --14/15--  Manchester City     2º   9  6  2  2  2     9º - 16º  2  0
# 1  2º  --14/15--        Liverpool     3º   5  6  1  2  3
# 2  3º  --14/15--          Chelsea     1º  14  6  4  2  0     9º - 16º  2  0
# 3  4º  --14/15--          Arsenal     2º  13  6  4  1  1     9º - 16º  2  1
#
#   EM DM  GP  GC  SG
# 0  0  2  10  11  -1
# 1         5   9  -4
# 2  2  0  20   6  14
# 3  0  1  18  11   7

# %% [markdown]
# # Champions League 15/16

# %%
CL1516 = [
    {"PL" : "1º",
    "Temporada" : "--15/16--",
    "Time" : "Chelsea",
    "Pos FG" : "1º",
    "PTS" : "13",
    "J" : "6",
    "V" : "4",
    "E" : "1",
    "D" : "1",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "0",
    "DM" : "2",
    "GP" : "15",
    "GC" : "7",
    "SG" : "8"},
    
    {"PL" : "2º",
    "Temporada" : "--15/16--",
    "Time" : "Manchester City",
    "Pos FG" : "1º",
    "PTS" : "12",
    "J" : "6",
    "V" : "4",
    "E" : "0",
    "D" : "2",
    "||" : "",
    "Pos MM" : "3º - 4º",
    "JM" : "6",
    "VM" : "2",
    "EM" : "3",
    "DM" : "1",
    "GP" : "18",
    "GC" : "12",
    "SG" : "6"},
    
    {"PL" : "3º",
    "Temporada" : "--15/16--",
    "Time" : "Arsenal",
    "Pos FG" : "2º",
    "PTS" : "9",
    "J" : "6",
    "V" : "3",
    "E" : "0",
    "D" : "3",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "0",
    "DM" : "2",
    "GP" : "13",
    "GC" : "15",
    "SG" : "-2"},
    
    {"PL" : "4º",
    "Temporada" : "--15/16--",
    "Time" : "Manchester Utd",
    "Pos FG" : "3º",
    "PTS" : "8",
    "J" : "6",
    "V" : "2",
    "E" : "2",
    "D" : "2",
    "||" : "",
    "Pos MM" : "",
    "JM" : "",
    "VM" : "",
    "EM" : "",
    "DM" : "",
    "GP" : "",
    "GC" : "",
    "SG" : ""}
]

# %%
df_CL1516 = pd.DataFrame(CL1516)

# %%
df_CL1516
# Out:
#    PL  Temporada             Time Pos FG PTS  J  V  E  D ||    Pos MM JM VM  \
# 0  1º  --15/16--          Chelsea     1º  13  6  4  1  1     9º - 16º  2  0
# 1  2º  --15/16--  Manchester City     1º  12  6  4  0  2      3º - 4º  6  2
# 2  3º  --15/16--          Arsenal     2º   9  6  3  0  3     9º - 16º  2  0
# 3  4º  --15/16--   Manchester Utd     3º   8  6  2  2  2
#
#   EM DM  GP  GC  SG
# 0  0  2  15   7   8
# 1  3  1  18  12   6
# 2  0  2  13  15  -2
# 3

# %% [markdown]
# # Champions League 16/17

# %%
CL1617 = [
    {"PL" : "1º",
    "Temporada" : "--16/17--",
    "Time" : "Leicester",
    "Pos FG" : "1º",
    "PTS" : "13",
    "J" : "6",
    "V" : "4",
    "E" : "1",
    "D" : "1",
    "||" : "",
    "Pos MM" : "5º - 8º",
    "JM" : "4",
    "VM" : "1",
    "EM" : "1",
    "DM" : "2",
    "GP" : "11",
    "GC" : "10",
    "SG" : "1"},
    
    {"PL" : "2º",
    "Temporada" : "--16/17--",
    "Time" : "Arsenal",
    "Pos FG" : "1º",
    "PTS" : "14",
    "J" : "6",
    "V" : "4",
    "E" : "2",
    "D" : "0",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "0",
    "DM" : "2",
    "GP" : "20",
    "GC" : "16",
    "SG" : "4"},
    
    {"PL" : "3º",
    "Temporada" : "--16/17--",
    "Time" : "Tottenham",
    "Pos FG" : "3º",
    "PTS" : "7",
    "J" : "6",
    "V" : "2",
    "E" : "1",
    "D" : "3",
    "||" : "",
    "Pos MM" : "",
    "JM" : "",
    "VM" : "",
    "EM" : "",
    "DM" : "",
    "GP" : "6",
    "GC" : "6",
    "SG" : "0"},
    
    {"PL" : "4º",
    "Temporada" : "--16/17--",
    "Time" : "Manchester City",
    "Pos FG" : "2º",
    "PTS" : "9",
    "J" : "6",
    "V" : "2",
    "E" : "3",
    "D" : "1",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "1",
    "EM" : "0",
    "DM" : "1",
    "GP" : "18",
    "GC" : "16",
    "SG" : "2"}
]

# %%
df_CL1617 = pd.DataFrame(CL1617)

# %%
df_CL1617
# Out:
#    PL  Temporada             Time Pos FG PTS  J  V  E  D ||    Pos MM JM VM  \
# 0  1º  --16/17--        Leicester     1º  13  6  4  1  1      5º - 8º  4  1
# 1  2º  --16/17--          Arsenal     1º  14  6  4  2  0     9º - 16º  2  0
# 2  3º  --16/17--        Tottenham     3º   7  6  2  1  3
# 3  4º  --16/17--  Manchester City     2º   9  6  2  3  1     9º - 16º  2  1
#
#   EM DM  GP  GC SG
# 0  1  2  11  10  1
# 1  0  2  20  16  4
# 2         6   6  0
# 3  0  1  18  16  2

# %% [markdown]
# # Champions League 17/18

# %%
CL1718 = [
    {"PL" : "1º",
    "Temporada" : "--17/18--",
    "Time" : "Chelsea",
    "Pos FG" : "2º",
    "PTS" : "11",
    "J" : "6",
    "V" : "3",
    "E" : "2",
    "D" : "1",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "1",
    "DM" : "1",
    "GP" : "17",
    "GC" : "12",
    "SG" : "5"},
    
    {"PL" : "2º",
    "Temporada" : "--17/18--",
    "Time" : "Tottenham",
    "Pos FG" : "1º",
    "PTS" : "16",
    "J" : "6",
    "V" : "5",
    "E" : "1",
    "D" : "0",
    "||" : "",
    "Pos MM" : "9º - 16º",
    "JM" : "2",
    "VM" : "0",
    "EM" : "1",
    "DM" : "1",
    "GP" : "18",
    "GC" : "8",
    "SG" : "10"},
    
    {"PL" : "3º",
    "Temporada" : "--17/18--",
    "Time" : "Manchester City",
    "Pos FG" : "1º",
    "PTS" : "15",
    "J" : "6",
    "V" : "5",
    "E" : "0",
    "D" : "1",
    "||" : "",
    "Pos MM" : "5º - 8º",
    "JM" : "4",
    "VM" : "1",
    "EM" : "0",
    "DM" : "3",
    "GP" : "20",
    "GC" : "12",
    "SG" : "8"},
    
    {"PL" : "4º",
    "Temporada" : "--17/18--",
    "Time" : "Liverpool",
    "Pos FG" : "1º",
    "PTS" : "12",
    "J" : "6",
    "V" : "3",
    "E" : "3",
    "D" : "0",
    "||" : "",
    "Pos MM" : "2º",
    "JM" : "7",
    "VM" : "4",
    "EM" : "1",
    "DM" : "2",
    "GP" : "41",
    "GC" : "16",
    "SG" : "25"}
]

# %%
df_CL1718 = pd.DataFrame(CL1718)

# %%
df_CL1718
# Out:
#    PL  Temporada             Time Pos FG PTS  J  V  E  D ||    Pos MM JM VM  \
# 0  1º  --17/18--          Chelsea     2º  11  6  3  2  1     9º - 16º  2  0
# 1  2º  --17/18--        Tottenham     1º  16  6  5  1  0     9º - 16º  2  0
# 2  3º  --17/18--  Manchester City     1º  15  6  5  0  1      5º - 8º  4  1
# 3  4º  --17/18--        Liverpool     1º  12  6  3  3  0           2º  7  4
#
#   EM DM  GP  GC  SG
# 0  1  1  17  12   5
# 1  1  1  18   8  10
# 2  0  3  20  12   8
# 3  1  2  41  16  25

# %% [markdown]
# # Champions League 18/19
